# %% [markdown]
# # SpinEDA: Análisis exploratorio, NLP y + de la obra de Luis alberto Spinetta

# %% [markdown]
# Disclaimer: El proyecto tiene como objetivos ayudarme a aprender e incorporar diversos conceptos de python (usar APIs x ejemplo) y data science. Es probable que haya errores, formas de hacer mejor las cosas, etc. Se aceptan sugerencias de todo tipo.

# %% [markdown]
# # Libraries y funciones

# %%
import pandas as pd
#import matplotlib.pyplot as plt
#import seaborn as sns
import numpy as np
import feather
from IPython.display import clear_output
from config import SPOT_CLIENT_ID, SPOT_CLIENT_SECRET, GENIUS_CLIENT_ID, GENIUS_CLIENT_SECRET, GENIUS_CLIENT_TOKEN

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
def print_full(df):
    """
    Mostrar el dataframe completo, no solo el head y tail.
    
    df: Pandas.DataFrame object
    """
    #pd.set_option('display.max_rows', len(df))
    #display(df)
    #pd.reset_option('display.max_rows')
    with pd.option_context("display.max_rows", len(df), "display.max_columns", len(df.columns)):
        display(df)

# %% [markdown]
# ***

# %% [markdown]
# # Spotify "scraping"

# %% [markdown]
# La idea es:
# - Aprender a usar la API de spotify, en este a travaés de la librería Spotipy (python friendly API)
# - Inicialmente pensé en usar la tabla de [Wikipedia](https://es.wikipedia.org/wiki/Anexo:Canciones_de_Luis_Alberto_Spinetta#1966_-_2020) que lista sus canciones, pero encontré varios problemas como que no contiene todos los temas de cada disco (no hay repeticiones por ejemplo, si el track X está en uno en vivo no aparece quizá en su versión de estudio), hay errores de variado tipo, no está separado el nro de track ni duración de cada track, faltaba el disco póstumo de principios de 2020 (lo tuve que agregar 💪), etc. así que esperamos con quizá un poco más de trabajo, obtener más información desde spotify.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
scope = 'user-library-read'
client_credentials_manager = SpotifyClientCredentials(client_id=SPOT_CLIENT_ID,
                                                      client_secret=SPOT_CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
#Esconder el request response (headers, get, etc)
sp.trace=False

# %%
artistas_id = {'Luis Alberto Spinetta': '', 'Invisible': '', 
               'Spinetta Jade': '', 
               'Almendra': '',
               'Pescado Rabioso': '',
               'Spinetta y los socios del desierto': ''}

# %% [markdown]
# Veamos un sample de la respuesta

# %%
sp.search(q='Almendra', type='artist')
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Almendra&type=artist&offset=0&limit=10',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7x2a9uyqlWbE9LwcoQWDTo'},
#     'followers': {'href': None, 'total': 156007},
#     'genres': ['argentine indie',
#      'argentine rock',
#      'latin alternative',
#      'latin rock',
#      'rock en espanol',
#      'rock nacional'],
#     'href': 'https://api.spotify.com/v1/artists/7x2a9uyqlWbE9LwcoQWDTo',
#     'id': '7x2a9uyqlWbE9LwcoQWDTo',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ca4882e0e7595714deeaefe3f66b9c17680c7d3c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/31fd6d92426b3f223eb0a3dcd19468d94a002eac',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/205be44e74d4e045acb6e4a5dd495adab7caf5d4',
#       'width': 64}],
#     'name': 'Almendra',
#     'popularity': 54,
#     'type': 'artist',
#     'uri': 'spotify:artist:7x2a9uyqlWbE9LwcoQWDTo'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/02pDmbzJ8d7qhudBcJ1m84'},
#     'followers': {'href': None, 'total': 66},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/02pDmbzJ8d7qhudBcJ1m84',
#     'id': '02pDmbzJ8d7qhudBcJ1m84',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image
},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5wHg6b8Bh2dbMaXHcOjjGF'},
#     'followers': {'href': None, 'total': 655},
#     'genres': ['cumbia ranchera'],
#     'href': 'https://api.spotify.com/v1/artists/5wHg6b8Bh2dbMaXHcOjjGF',
#     'id': '5wHg6b8Bh2dbMaXHcOjjGF',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/bb0b1040184b4df005b7859dce554f90475ba4e2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/6cb63868fadf991c157e2975e77c67224be69013',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/2c72fc6cf1d321b182b073b499588d07d263ea9e',
#       'width': 64}],
#     'name': 'Sebastián Almendras',
#     'popularity': 31,
#     'type': 'artist',
#     'uri': 'spotify:artist:5wHg6b8Bh2dbMaXHcOjjGF'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0Ga2UNELZT7ZpOcC6P410D'},
#     'followers': {'href': None, 'total': 29},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/0Ga2UNELZT7ZpOcC6P410D',
#     'id': '0Ga2UNELZT7ZpOcC6P410D',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731090efd1c596bd7cf42b16bb',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021090efd1c596bd7cf42b16bb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511090efd1c596bd7cf42b16bb',
#       'width': 64}],
#     'name': 'Almendra Fran',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:0Ga2UNELZT7ZpOcC6P410D'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=Almendra&type=artist&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 55}}

# %% [markdown]
# From Spotipy docs: Spotipy supports a number of different ID types:
#
#         Spotify URI - The resource identifier that you can enter, for example, in the Spotify Desktop client’s search box to locate an artist, album, or track. Example: spotify:track:6rqhFgbbKwnb9MLmUQDhG6
#         Spotify URL - An HTML link that opens a track, album, app, playlist or other Spotify resource in a Spotify client. Example: http://open.spotify.com/track/6rqhFgbbKwnb9MLmUQDhG6
#         Spotify ID - A base-62 number that you can find at the end of the Spotify URI (see above) for an artist, track, album, etc. Example: 6rqhFgbbKwnb9MLmUQDhG6
#
# In general, any Spotipy method that needs an artist, album, track or playlist ID will accept ids in any of the above form

# %% [markdown]
# ***

# %% [markdown]
# Spotipy nos devuelve un diccionario medio nesteado con información variada de los artistas que matchean. Dada la popularidad del flaco, vamos a limitarnos al primer resultado, si estamos pifiando, luego lo sabremos.
# Vamos a obtener el **id** asignado por spotify a cada artista para luego buscar todos respectivos álbumes y tracks.

# %%
for banda in artistas_id:
    artistas_id[banda] = sp.search(q=banda, type='artist', limit=1)[
        'artists']['items'][0]['id']

artistas_id
# Out:
# {'Luis Alberto Spinetta': '1MuQ2m2tg7naeRGAOxYZer',
#  'Invisible': '3FjdJbt6Myq32uv7P4owM1',
#  'Spinetta Jade': '3WxVICwFDAWMTWH8sELmRe',
#  'Almendra': '7x2a9uyqlWbE9LwcoQWDTo',
#  'Pescado Rabioso': '3q1NXsv9XypOUCJfEatXH9',
#  'Spinetta y los socios del desierto': '7F5m9Jw4sg853wTDmmJvLi'}

# %% [markdown]
# Obtengamos los discos: artist_albums devuelve un dict donde key='items' es una lista con cada disco. De cada disco nos interesa  `id`, `name`, `album_type`, `total_tracks` y `release_date`. La API tiene un límite de 50 resultados por request. Por otro lado spotify tiene mal catalogado varios discos (figuran como albums pero son compilados), etc.

# %%
def get_albums_info(artist_id, album_type=None):
    '''
    artist_id: spotify id (https://spotipy.readthedocs.io/en/2.7.1/#ids-uris-and-urls)
    album_type: 'album', 'single', 'appears_on', 'compilation'. 
    Si album_type > 1 elemento, tiene que ser un string separado por comas: 'album,single'
    '''
    albums = []
    next_p = '_'
    offset = 0
    while next_p:
        alb_page = sp.artist_albums(
            artist_id, limit=50, offset=offset, album_type=album_type)

        albums.extend([(album['artists'][0]['name'], album['name'], album['album_type'],
                        album['release_date'], album['total_tracks'], album['id']) for album in alb_page['items']])
        offset += 50
        next_p = alb_page['next']
    return albums

# %%
full_list = []
for album_id in artistas_id.values():
    full_list.extend(get_albums_info(artist_id=album_id, album_type='album,single'))

# %%
albums_df = pd.DataFrame(data=full_list, columns=[
                         'Artista', 'Album', 'Tipo', 'Año', 'Total tracks', 'id'])
albums_df['Año'] = albums_df['Año'].apply(lambda x: x[:4])
print_full(albums_df)
# Out:
#                                Artista  \
# 0                Luis Alberto Spinetta
# 1                Luis Alberto Spinetta
# 2                Luis Alberto Spinetta
# 3                Luis Alberto Spinetta
# 4                            Fito Paez
# 5                Luis Alberto Spinetta
# 6                Luis Alberto Spinetta
# 7                Luis Alberto Spinetta
# 8                Luis Alberto Spinetta
# 9                Luis Alberto Spinetta
# 10               Luis Alberto Spinetta
# 11               Luis Alberto Spinetta
# 12               Luis Alberto Spinetta
# 13               Luis Alberto Spinetta
# 14               Luis Alberto Spinetta
# 15               Luis Alberto Spinetta
# 16               Luis Alberto Spinetta
# 17               Luis Alberto Spinetta
# 18               Luis Alberto Spinetta
# 19                           Fito Paez
# 20               Luis Alberto Spinetta
# 21               Luis Alberto Spinetta
# 22               Luis Alberto Spinetta
# 23               Luis Alberto Spinetta
# 24               Luis Alberto Spinetta
# 25                     Rodolfo Mederos
# 26               Luis Alberto Spinetta
# 27               Luis Alberto Spinetta
# 28               Luis Alberto Spinetta
# 29               Luis Alberto Spinetta
# 30                           Invisible
# 31                           Invisible
# 32                           Invisible
# 33                           Invisible
# 34                           Invisible
# 35                       Spinetta Jade
# 36                       Spinetta Jade
# 37                       Spinetta Jade
# 38                       Spinetta Jade
# 39                            Almendra
# 40                            Almendra
# 41                            Almendra
# 42                            Almendra
# 43                            Almendra
# 44                            Almendra
# 45                            Almendra
# 46                            Almendra
# 47                            Almendra
# 48                            Almendra
# 49                     Pescado Rabioso
# 50                     Pescado Rabioso
# 51                     Pescado Rabioso
# 52                     Pescado Rabioso
# 53  Spinetta Y Los Socios Del Desierto
# 54  Spinetta Y Los Socios Del Desierto
#
#                                              Album    Tipo   Año  \
# 0                                Ya No Mires Atrás   album  2020
# 1                    Spinetta y Las Bandas Eternas   album  2010
# 2   Sí o Sí - Diario del Rock Argentino - Spinetta   album  2008
# 3                                        Un Mañana   album  2008
# 4                                         La La La   album  2007
# 5                                    Obras Cumbres   album  2006
# 6                                              Pan   album  2005
# 7                                 Para Los Arboles   album  2003
# 8     Argentina Sorgo Films (Live At Obras / 2001)   album  2002
# 9                                     Silver Sorgo   album  2001
# 10                                    Elija Y Gane   album  1999
# 11                                  San Cristóforo   album  1998
# 12                                        El Album   album  1994
# 13                                      Fuego Gris   album  1993
# 25             5  72VMjUaDmlKeEK0YaRt6h0
# 26            11  1leLP4q5kQpy53FvUNovTe
# 27             1  6JQXrcitGg2HYqWexJNWSo
# 28             1  3HJUuGjf3AqUUDMzyfwEe5
# 29             4  0ojPZ6Mtd0XEftaZlb77iV
# 30             8  0lbpA4dCZfaNhy6LZrGDvJ
# 31             5  4Cf6WflKk1FEtffkm9h1U7
# 32             6  2pyzrjcMOZrYsghQjRz7Xo
# 33             8  6sLgLblHq0HqTGx4Jxao0y
# 34             5  6a90NggrTFyttykVIYwNY1
# 35             9  7IOzpHYubvSUBNzeyEWwKB
# 36            10  3pFMaPwaHb6D0EkMtRlaO9
# 37            10  1EvxxViNArpX7YXmgMd4Zw
# 38             7  08WhOkH7KtcbYzyxfMuV2R
# 39            20  6dbcAi0JArvnnqOcFlWd7N
# 40            20  1ZJWsjJ0iUTsE5JsjENnz0
# 41            12  1lHQB6PixGI8RL4O5Q55A1
# 42            39  63KkbkY4eFB82Ee9H8o2Qb
# 43            20  2Syxpgpva5hDmqCZpmmJHp
# 44             7  496i1vWJDZv6MFMX6vI8Th
# 45            13  4IPyrM8pEQgAqzHSVzPQHV
# 46            21  4MsNzFYnP4twrraRWNFjqJ
# 47            21  1UApSv84QQ57hVZe8mbGWw
# 48             9  23jZzJ9u5M9p03nf84zuO1
# 49            11  3XxDmLiEBKqFu1MiZ3fayw
# 50             9  5MJR9j21vjEi4ODxzhvoTA
# 51            18  3j9nlCtanXCPvoaFzrpjPs
# 52             5  4K0JVP5veNYTVI6IMamlla
# 53            14  3mL0B9P4bNWpxfOVkCKL93
# 54            33  04sd3yVEomRHkJ6Qd3KXBt

# %% [markdown]
# No es perfecto, pero es lo que hay. Vamos a sacar compilados y algunos repetidos.

# %%
albums_df.drop([2,4, 5, 10, 12, 17, 19, 33, 39, 40, 41, 42, 43, 47, 49], inplace=True)

# %% [markdown]
# Vamos también a dropear los discos en vivo y Singles/EPs por el momento y guardar en otro df

# %%
albums_studio_df = albums_df.drop(albums_df[albums_df['Tipo'] == 'single'].index)
albums_studio_df.drop([1,8,11,15, 25, 45], inplace=True)

# %%
print_full(albums_studio_df)
# Out:
#                                Artista                               Album  \
# 0                Luis Alberto Spinetta                   Ya No Mires Atrás
# 3                Luis Alberto Spinetta                           Un Mañana
# 6                Luis Alberto Spinetta                                 Pan
# 7                Luis Alberto Spinetta                    Para Los Arboles
# 9                Luis Alberto Spinetta                        Silver Sorgo
# 13               Luis Alberto Spinetta                          Fuego Gris
# 14               Luis Alberto Spinetta                     Peluson Of Milk
# 16               Luis Alberto Spinetta                          Don Lucero
# 18               Luis Alberto Spinetta                 Tester de Violencia
# 20               Luis Alberto Spinetta                               Prive
# 21               Luis Alberto Spinetta                      Mondo Di Cromo
# 22               Luis Alberto Spinetta                            Kamikaze
# 23               Luis Alberto Spinetta               Only Love Can Sustain
# 24               Luis Alberto Spinetta                       A 18' Del Sol
# 26               Luis Alberto Spinetta         Spinettalandia y Sus Amigos
# 30                           Invisible          El Jardin de los Presentes
ists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  disc_number  \
# 0  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...            1
# 1  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...            1
# 2  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...            1
# 3  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...            1
# 4  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...            1
#
#    duration_ms  explicit                                      external_urls  \
# 0       226226     False  {'spotify': 'https://open.spotify.com/track/2r...
# 1       182773     False  {'spotify': 'https://open.spotify.com/track/6w...
# 2       209293     False  {'spotify': 'https://open.spotify.com/track/3A...
# 3       306040     False  {'spotify': 'https://open.spotify.com/track/1q...
# 4       196160     False  {'spotify': 'https://open.spotify.com/track/2J...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/2ri0lTjVeBkW...  2ri0lTjVeBkWAmRVkJoHXL
# 1  https://api.spotify.com/v1/tracks/6wGKkvlvUHbd...  6wGKkvlvUHbdi6hlp3C8q7
# 2  https://api.spotify.com/v1/tracks/3AIa10wSpvJp...  3AIa10wSpvJpugn8gZmeYv
# 3  https://api.spotify.com/v1/tracks/1qf2RbvAdkOr...  1qf2RbvAdkOrjKeBmSYzXV
# 4  https://api.spotify.com/v1/tracks/2JwfGxkK4BrW...  2JwfGxkK4BrWTCw0QQjGXN
#
#    is_local                      name  \
# 0     False          Post-Crucifixion
# 1     False                 Nena Boba
# 2     False             Blues de Cris
# 3     False  Como el Viento Voy a Ver
# 4     False          Despiértate Nena
#
#                                          preview_url  track_number   type  \
# 0  https://p.scdn.co/mp3-preview/7b6382a37b3a21d8...             1  track
# 1  https://p.scdn.co/mp3-preview/b03f6a3e1e386d2a...             2  track
# 2  https://p.scdn.co/mp3-preview/fe11c6425ee3afb2...             3  track
# 3  https://p.scdn.co/mp3-preview/751460e6a36e37fd...             4  track
# 4  https://p.scdn.co/mp3-preview/0321c92cbbf42580...             5  track
#
#                                     uri
# 0  spotify:track:2ri0lTjVeBkWAmRVkJoHXL
# 1  spotify:track:6wGKkvlvUHbdi6hlp3C8q7
# 2  spotify:track:3AIa10wSpvJpugn8gZmeYv
# 3  spotify:track:1qf2RbvAdkOrjKeBmSYzXV
# 4  spotify:track:2JwfGxkK4BrWTCw0QQjGXN

# %%
df_tracks = pd.DataFrame()
col_utiles = zip(albums_studio_df['Artista'], albums_studio_df['Album'],
                 albums_studio_df['Año'], albums_studio_df['id'])

for art, alb, año, alb_id in col_utiles:
    sp_response = pd.DataFrame(sp.album_tracks(alb_id)['items'])
    sp_response['Artista'], sp_response['Album'], sp_response['Año'] = art, alb, año
    df_tracks = pd.concat([df_tracks, sp_response], axis=0,
                          join='outer', ignore_index=True)

# %%
df_tracks
# Out:
#                                                artists  \
# 0    [{'external_urls': {'spotify': 'https://open.s...
# 1    [{'external_urls': {'spotify': 'https://open.s...
# 2    [{'external_urls': {'spotify': 'https://open.s...
# 3    [{'external_urls': {'spotify': 'https://open.s...
# 4    [{'external_urls': {'spotify': 'https://open.s...
# ..                                                 ...
# 338  [{'external_urls': {'spotify': 'https://open.s...
# 339  [{'external_urls': {'spotify': 'https://open.s...
# 340  [{'external_urls': {'spotify': 'https://open.s...
# 341  [{'external_urls': {'spotify': 'https://open.s...
# 342  [{'external_urls': {'spotify': 'https://open.s...
#
#                                      available_markets  disc_number  \
# 0    [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            1
# 1    [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            1
# 2    [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            1
# 3    [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            1
# 4    [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            1
# ..                                                 ...          ...
# 338  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            2
# 339  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            2
# 340  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            2
# 341  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            2
# 342  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            2
#
#      duration_ms  explicit                                      external_urls  \
# 0         179130     False  {'spotify': 'https://open.spotify.com/track/17...
# 1         223532     False  {'spotify': 'https://open.spotify.com/track/53...
# 2         326647     False  {'spotify': 'https://open.spotify.com/track/1S...
# 3         353587     False  {'spotify': 'https://open.spotify.com/track/1z...
# 4         267527     False  {'spotify': 'https://open.spotify.com/track/1r...
# ..           ...       ...                                                ...
# 338       216506     False  {'spotify': 'https://open.spotify.com/track/2r...
# 339        49133     False  {'spotify': 'https://open.spotify.com/track/0L...
# 340       235866     False  {'spotify': 'https://open.spotify.com/track/40...
# 341       145560     False  {'spotify': 'https://open.spotify.com/track/2y...
# 342        51106     False  {'spotify': 'https://open.spotify.com/track/5m...
#
#                                                   href  \
# 0    https://api.spotify.com/v1/tracks/17a6EMs038tu...
# 1    https://api.spotify.com/v1/tracks/535rcofAUexz...
# 2    https://api.spotify.com/v1/tracks/1Sa25LKUNSTC...
# 3    https://api.spotify.com/v1/tracks/1zZCrhlS7oUs...
# 4    https://api.spotify.com/v1/tracks/1rabqQO8uUz8...
# ..                                                 ...
# 338  https://api.spotify.com/v1/tracks/2rGHar8C29r3...
# 339  https://api.spotify.com/v1/tracks/0Lnk6DhCuPb0...
# 340  https://api.spotify.com/v1/tracks/40V9rPDytBeE...
# 341  https://api.spotify.com/v1/tracks/2ygmx2TzNLGe...
# 342  https://api.spotify.com/v1/tracks/5mUTfWJizhtT...
#
#                          id  is_local                              name  \
# 0    17a6EMs038tuh87eggDJ1G     False                   Veinte Ciudades
# 1    535rcofAUexzCqS9xHkVkv     False                 Ya No Mires Atrás
# 2    1Sa25LKUNSTCxfd1METeBT     False                       Agua de Río
# 3    1zZCrhlS7oUsAs3rjGfmJK     False            Nueva Luna, Mundo Arjo
# 4    1rabqQO8uUz86di4NkbVPo     False                           Merecer
# ..                      ...       ...                               ...
# 338  2rGHar8C29r3t1wExKeuQb     False                        2 de Enero
# 339  0Lnk6DhCuPb0UmAXMZWz2O     False                     Cuenco de Sal
# 340  40V9rPDytBeEp7xutQjtDR     False  El Sol y la Afeitadora Eléctrica
# 341  2ygmx2TzNLGeHp4DNvgXAQ     False                            Collar
# 342  5mUTfWJizhtTGyzRKWxxxO     False                            Duende
#
#                                            preview_url  track_number   type  \
# 0    https://p.scdn.co/mp3-preview/81f84acf06679ce9...             1  track
# 1    https://p.scdn.co/mp3-preview/bc1bb2c34d329c7c...             2  track
# 2    https://p.scdn.co/mp3-preview/415c24347e8ae116...             3  track
# 3    https://p.scdn.co/mp3-preview/eac1fbb2da4acb46...             4  track
# 4    https://p.scdn.co/mp3-preview/212e0d4e527aec6f...             5  track
# ..                                                 ...           ...    ...
# 338  https://p.scdn.co/mp3-preview/f695b9e973583d79...            12  track
# 339  https://p.scdn.co/mp3-preview/3709b57a58097f3b...            13  track
# 340  https://p.scdn.co/mp3-preview/686770ee5b79c748...            14  track
# 341  https://p.scdn.co/mp3-preview/846c45ee8ca737ab...            15  track
# 342  https://p.scdn.co/mp3-preview/a1b4965c22f7ea3c...            16  track
#
#                                       uri                             Artista  \
# 0    spotify:track:17a6EMs038tuh87eggDJ1G               Luis Alberto Spinetta
# 1    spotify:track:535rcofAUexzCqS9xHkVkv               Luis Alberto Spinetta
# 2    spotify:track:1Sa25LKUNSTCxfd1METeBT               Luis Alberto Spinetta
# 3    spotify:track:1zZCrhlS7oUsAs3rjGfmJK               Luis Alberto Spinetta
# 4    spotify:track:1rabqQO8uUz86di4NkbVPo               Luis Alberto Spinetta
# ..                                    ...                                 ...
# 338  spotify:track:2rGHar8C29r3t1wExKeuQb  Spinetta Y Los Socios Del Desierto
# 339  spotify:track:0Lnk6DhCuPb0UmAXMZWz2O  Spinetta Y Los Socios Del Desierto
# 340  spotify:track:40V9rPDytBeEp7xutQjtDR  Spinetta Y Los Socios Del Desierto
# 341  spotify:track:2ygmx2TzNLGeHp4DNvgXAQ  Spinetta Y Los Socios Del Desierto
# 342  spotify:track:5mUTfWJizhtTGyzRKWxxxO  Spinetta Y Los Socios Del Desierto
#
#                                   Album   Año
# 0                     Ya No Mires Atrás  2020
# 1                     Ya No Mires Atrás  2020
# 2                     Ya No Mires Atrás  2020
# 3                     Ya No Mires Atrás  2020
# 4                     Ya No Mires Atrás  2020
# ..                                  ...   ...
# 338  Spinetta y los Socios del Desierto  1997
# 339  Spinetta y los Socios del Desierto  1997
# 340  Spinetta y los Socios del Desierto  1997
# 341  Spinetta y los Socios del Desierto  1997
# 342  Spinetta y los Socios del Desierto  1997
#
# [343 rows x 17 columns]

# %%
for idx, row in df_tracks.iterrows():
    
    #audio_analysis = sp.audio_analysis(row['id'])['track']
    audio_features = sp.audio_features([row['id']])[0]
    df_tracks.at[idx, 'Duration'] = audio_features['duration_ms']
    df_tracks.at[idx, 'Acousticness'] = audio_features['acousticness']
    df_tracks.at[idx, 'Danceability'] = audio_features['danceability']
    df_tracks.at[idx, 'Energy'] = audio_features['energy']
    df_tracks.at[idx, 'Instrumentalness'] = audio_features['instrumentalness']
    df_tracks.at[idx, 'Liveness'] = audio_features['liveness']
    df_tracks.at[idx, 'Loudness'] = audio_features['loudness']
    df_tracks.at[idx, 'Speechiness'] = audio_features['speechiness']
    df_tracks.at[idx, 'Key'] = audio_features['key']
    df_tracks.at[idx, 'Tempo'] = audio_features['tempo']
    df_tracks.at[idx, 'Time_signature'] = audio_features['time_signature']
    df_tracks.at[idx, 'Valence'] = audio_features['valence']
    df_tracks.at[idx, 'Mode'] = audio_features['mode']
    clear_output(wait=True)
    print(idx)
    #print(idx, df_tracks.iloc[idx])
# Out:
# 342

# %%
df_tracks
# Out:
#                                                artists  \
# 0    [{'external_urls': {'spotify': 'https://open.s...
# 1    [{'external_urls': {'spotify': 'https://open.s...
# 2    [{'external_urls': {'spotify': 'https://open.s...
# 3    [{'external_urls': {'spotify': 'https://open.s...
# 4    [{'external_urls': {'spotify': 'https://open.s...
# ..                                                 ...
# 338  [{'external_urls': {'spotify': 'https://open.s...
# 339  [{'external_urls': {'spotify': 'https://open.s...
# 340  [{'external_urls': {'spotify': 'https://open.s...
# 341  [{'external_urls': {'spotify': 'https://open.s...
# 342  [{'external_urls': {'spotify': 'https://open.s...
#
#                                      available_markets  disc_number  \
# 0    [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            1
# 1    [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            1
# 2    [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            1
# 3    [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            1
# 4    [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            1
# ..                                                 ...          ...
# 338  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            2
# 339  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            2
# 340  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            2
# 341  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            2
# 342  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...            2
#
#      duration_ms  explicit                                      external_urls  \
# 0         179130     False  {'spotify': 'https://open.spotify.com/track/17...
# 1         223532     False  {'spotify': 'https://open.spotify.com/track/53...
# 2         326647     False  {'spotify': 'https://open.spotify.com/track/1S...
# 3         353587     False  {'spotify': 'https://open.spotify.com/track/1z...
# 4         267527     False  {'spotify': 'https://open.spotify.com/track/1r...
# ..           ...       ...                                                ...
# 338       216506     False  {'spotify': 'https://open.spotify.com/track/2r...
# 339        49133     False  {'spotify': 'https://open.spotify.com/track/0L...
# 340       235866     False  {'spotify': 'https://open.spotify.com/track/40...
# 341       145560     False  {'spotify': 'https://open.spotify.com/track/2y...
# 342        51106     False  {'spotify': 'https://open.spotify.com/track/5m...
#
#                                                   href  \
# 0    https://api.spotify.com/v1/tracks/17a6EMs038tu...
# 1    https://api.spotify.com/v1/tracks/535rcofAUexz...
# 2    https://api.spotify.com/v1/tracks/1Sa25LKUNSTC...
# 3    https://api.spotify.com/v1/tracks/1zZCrhlS7oUs...
# 4    https://api.spotify.com/v1/tracks/1rabqQO8uUz8...
# ..                                                 ...
# 338  https://api.spotify.com/v1/tracks/2rGHar8C29r3...
# 339  https://api.spotify.com/v1/tracks/0Lnk6DhCuPb0...
# 340  https://api.spotify.com/v1/tracks/40V9rPDytBeE...
# 341  https://api.spotify.com/v1/tracks/2ygmx2TzNLGe...
# 342  https://api.spotify.com/v1/tracks/5mUTfWJizhtT...
#
#                          id  is_local                              name  ...  \
# 0    17a6EMs038tuh87eggDJ1G     False                   Veinte Ciudades  ...
# 1    535rcofAUexzCqS9xHkVkv     False                 Ya No Mires Atrás  ...
# 2    1Sa25LKUNSTCxfd1METeBT     False                       Agua de Río  ...
# 3    1zZCrhlS7oUsAs3rjGfmJK     False            Nueva Luna, Mundo Arjo  ...
# 4    1rabqQO8uUz86di4NkbVPo     False                           Merecer  ...
# ..                      ...       ...                               ...  ...
# 338  2rGHar8C29r3t1wExKeuQb     False                        2 de Enero  ...
# 339  0Lnk6DhCuPb0UmAXMZWz2O     False                     Cuenco de Sal  ...
# 340  40V9rPDytBeEp7xutQjtDR     False  El Sol y la Afeitadora Eléctrica  ...
# 341  2ygmx2TzNLGeHp4DNvgXAQ     False                            Collar  ...
# 342  5mUTfWJizhtTGyzRKWxxxO     False                            Duende  ...
#
#     Energy  Instrumentalness Liveness Loudness Speechiness  Key    Tempo  \
# 0    0.794          0.000046   0.2210   -9.396      0.0350  6.0  123.029
# 1    0.524          0.002480   0.1500  -11.140      0.0276  6.0   79.985
# 2    0.644          0.009090   0.2770  -10.334      0.0318  7.0  114.989
# 3    0.472          0.000008   0.2700  -11.822      0.0318  2.0  116.831
# 4    0.669          0.000014   0.0984  -10.747      0.0492  2.0  141.955
# ..     ...               ...      ...      ...         ...  ...      ...
# 338  0.596          0.000018   0.1550   -6.132      0.0329  9.0  135.126
# 339  0.533          0.004760   0.0922  -10.536      0.0424  9.0  139.666
# 340  0.483          0.000002   0.2220   -7.699      0.0282  2.0  145.406
# 341  0.405          0.000026   0.1490   -9.758      0.0230  7.0   93.375
# 342  0.702          0.342000   0.2550  -11.140      0.1280  0.0  129.081
#
#      Time_signature  Valence  Mode
# 0               4.0    0.694   0.0
# 1               4.0    0.860   0.0
# 2               4.0    0.696   1.0
# 3               3.0    0.279   0.0
# 4               4.0    0.808   0.0
# ..              ...      ...   ...
# 338             4.0    0.390   0.0
# 339             4.0    0.148   1.0
# 340             4.0    0.411   1.0
# 341             3.0    0.193   1.0
# 342             4.0    0.810   1.0
#
# [343 rows x 30 columns]

# %%
df_tracks.columns
# Out:
# Index(['artists', 'available_markets', 'disc_number', 'duration_ms',
#        'explicit', 'external_urls', 'href', 'id', 'is_local', 'name',
#        'preview_url', 'track_number', 'type', 'uri', 'Artista', 'Album', 'Año',
#        'Duration', 'Acousticness', 'Danceability', 'Energy',
#        'Instrumentalness', 'Liveness', 'Loudness', 'Speechiness', 'Key',
#        'Tempo', 'Time_signature', 'Valence', 'Mode'],
#       dtype='object')

# %% [markdown]
# Borremos columnas inútiles

# %%
df_tracks.drop(['artists', 'available_markets', 'explicit', 'duration_ms',
                'external_urls', 'href', 'is_local',
                'preview_url', 'type', 'uri'], axis=1, inplace=True)

# %% [markdown]
# Rename & reorder

# %%
df_tracks.columns
# Out:
# Index(['disc_number', 'id', 'name', 'track_number', 'Artista', 'Album', 'Año',
#        'Duration', 'Acousticness', 'Danceability', 'Energy',
#        'Instrumentalness', 'Liveness', 'Loudness', 'Speechiness', 'Key',
#        'Tempo', 'Time_signature', 'Valence', 'Mode'],
#       dtype='object')

# %%
df_tracks.columns = ['Nro_disco', 'id', 'Nombre', 'Track_nro', 'Artista', 'Album', 
                     'Año', 'Duracion', 'Acousticness', 'Danceability', 'Energy',
                     'Instrumentalness', 'Liveness', 'Loudness', 'Speechiness', 'Key',
                     'Tempo', 'Time_signature', 'Valence', 'Mode']

# %%
df_tracks = df_tracks[['Nombre', 'Album', 'Artista', 'Track_nro', 'Nro_disco', 'Año',
                       'Duracion', 'Acousticness', 'Danceability', 'Energy',
                       'Instrumentalness', 'Liveness', 'Loudness', 'Speechiness', 'Key',
                       'Tempo', 'Time_signature', 'Valence', 'Mode','id']]

# %%
df_tracks.columns
# Out:
# Index(['Nombre', 'Album', 'Artista', 'Track_nro', 'Nro_disco', 'Año',
#        'Duracion', 'Acousticness', 'Danceability', 'Energy',
#        'Instrumentalness', 'Liveness', 'Loudness', 'Speechiness', 'Key',
#        'Tempo', 'Time_signature', 'Valence', 'Mode', 'id'],
#       dtype='object')

# %%
# 304             4.0   0.6360   0.0  7xrfeXdhqPZYtk3MqZEecZ
# 305             4.0   0.3540   0.0  0Kf9snjzyCXXVzOp9F2ACF
# 306             3.0   0.3220   1.0  4ehkQH5w1LTBmR23K2g36F
# 307             4.0   0.4970   0.0  4NgKNCa0pPqxWMF5iGDGEy
# 308             4.0   0.1420   1.0  0xjY1InQAPePzJAetKOLag
# 309             4.0   0.0645   0.0  5spEH3x0KlL4lzIDwVBkpB
# 310             4.0   0.6580   1.0  4sLeBVI7jCaDUd0WcxCWbg
# 311             4.0   0.5560   0.0  0ocOBqYDHVPL0kithZCBNa
# 312             4.0   0.4800   1.0  5Q25CeofNbs4uvqDQRl58w
# 313             4.0   0.4860   1.0  1eB2JD5WO15AHERxW4W414
# 314             4.0   0.1070   1.0  5kkxgUKPjX7A4ySvJIH6ZP
# 315             4.0   0.3910   0.0  2F7ePQhoKNRJAAHXFPtwbo
# 316             3.0   0.6310   0.0  0cKu6kqvm9cYRJT6qBtkW2
# 317             4.0   0.5780   1.0  2RmwSfGS5zfYioAELovTyN
# 318             4.0   0.7730   1.0  1RJB2C0VYYA7Z0WUOUjhe5
# 319             4.0   0.0851   1.0  2Hzears702Jox63eWjxpP0
# 320             4.0   0.7140   1.0  4uUlr2RFvscPcnz3fnve8L
# 321             4.0   0.5970   1.0  4fSNLsxD14QFcdPBthjiic
# 322             4.0   0.6820   1.0  6YN5leAy3mw9393GNJBdYs
# 323             3.0   0.1530   1.0  3crZ4GsZJrCAkkPVRQlQ6M
# 324             3.0   0.2200   0.0  4iLsvtyr4Ut9EHWqCjLN8X
# 325             3.0   0.4000   1.0  3s6ycBUMjgOmhd7CF5htjr
# 326             4.0   0.1010   1.0  6T5WuepPHnRzBAhohSAeXt
# 327             4.0   0.6160   1.0  3qBwLmGiqRvBqrzfcsl9Fp
# 328             4.0   0.6720   1.0  673LL4gFJTCnN49guuWI0i
# 329             4.0   0.2880   1.0  6qJ7VkKR8g817ZEAFU6EQt
# 330             4.0   0.4970   1.0  7FiEODPklnxll58nJV1jfW
# 331             4.0   0.4350   1.0  1zYeS19z1Ucwgj5ovzCeQT
# 332             4.0   0.6020   0.0  1VBcoqPvMf48QrZT7uOsjt
# 333             4.0   0.3320   0.0  6ygWo0isEGUX2eupoptSqn
# 334             4.0   0.5500   0.0  5dR7BsTV5JAnyGvQqOyr4o
# 335             4.0   0.3830   0.0  2c30vGB2GC6iltdS1pZlgm
# 336             3.0   0.4070   1.0  4LhPP2X0j4m3JaCzrsHO0S
# 337             4.0   0.3180   1.0  4OGvzKuzsd5OfToR6n4neB
# 338             4.0   0.3900   0.0  2rGHar8C29r3t1wExKeuQb
# 339             4.0   0.1480   1.0  0Lnk6DhCuPb0UmAXMZWz2O
# 340             4.0   0.4110   1.0  40V9rPDytBeEp7xutQjtDR
# 341             3.0   0.1930   1.0  2ygmx2TzNLGeHp4DNvgXAQ
# 342             4.0   0.8100   1.0  5mUTfWJizhtTGyzRKWxxxO

# %%
df_tracks.at[49, 'Nombre'] = 'Abrázame Inocentemente'

# %% [markdown]
# Guardamos el dataframe

# %%
df_tracks.to_feather('Tracks')

# %% [markdown]
# # Tracks letras

# %%
#df_tracks = pd.read_feather('tracks')

# %%
import lyricsgenius

# %%
genius = lyricsgenius.Genius(GENIUS_CLIENT_TOKEN, sleep_time=1)
genius.verbose = False # Turn off status messages
genius.remove_section_headers = True # Remove section headers (e.g. [Chorus]) from lyrics when searching
genius.skip_non_songs = False # Include hits thought to be non-songs (e.g. track lists)
genius.excluded_terms = ["(Remix)", "(Live)"] # Exclude songs with these words in their title

# %%
df_tracks['Letra'] = ''

# %%
def get_lyrics():
#REVISAR POR QUE not_found  SE VACÍA EN EL ÚLTIMO CICLO
#si no encuentra la letra, salta un AttributeError, así que hay que agarrarlo
#luego analizamos cuáles fallaron a ver por qué

    not_found = []

    for i in df_tracks.index:
        art = df_tracks.loc[i, 'Artista']
        nom = df_tracks.loc[i, 'Nombre']
        
        if df_tracks.loc[i, 'Letra'] == '':
            try:
                letra = genius.search_song(nom, artist=art, get_full_info=False)
                df_tracks.at[i, 'Letra'] = letra.lyrics
                print(letra.lyrics)
                clear_output(wait=True)
            except AttributeError:
                not_found.append((i,nom))
                print(*not_found,sep='\n')
                clear_output(wait=True)
                continue

# %%
get_lyrics()
# Out:
# (118, 'Paquidermo De Luxe - Instrumental')
# (122, 'Símil Bahion - Instrumental')
# (127, 'El Bálsamo - Instrumental')
# (128, 'Para Valen - Instrumental')
# (130, 'Tango Cromado - Instrumental')
# (135, 'Almendra')
# (146, 'Interlude (Jade I)')
# (147, 'Interlude (Jade II)')
# (152, 'Interlude (Jade III)')
# (154, 'Telgopor')
# (156, 'A Dieciocho Minutos del Sol')
# (163, 'Tema de Pedro')
# (165, 'Estrella')
# (169, 'Alteración de Tiempo')
# (174, 'Alarma Entre Los Angeles')
# (188, 'Tema de Elmo Lesto')
# (198, 'Mula Alma - Instrumental')
# (204, 'Ping Pong - Instrumental')
# (214, 'Siguiendo Los Pasos Del Maestro')
# (218, 'Influjo Estelar')
# (220, 'Amenábar')
# (225, 'Digital Ayatollah')
# (248, 'Obertura (Obertura Beat)')
# (250, 'Verde Llano')
# (273, 'Panadero Ensoñado')
# (283, 'Señorita Zapada')
# (290, 'Aguas Claras de Olimpos')
# (296, 'Ven Vení')
# (297, 'Ave Seca')
# (298, 'Donde No Se Lee')
# (299, 'Extiéndete Una Vez Más')
# (300, 'No Me Alcanza')
# (301, 'Ekathé I')
# (302, 'Nómbrala')
# (303, 'Bahía Final')
# (305, 'Bagatelle')
# (306, 'Ekathé II - Mono')
# (307, 'La Flor')
# (308, 'Guíame')
# (309, 'Vera')
# (312, 'Los Duendes')
# (313, 'Sub Rebaño')
# (318, 'Oh! Magnolia')
# (321, 'Tony')
# (322, 'Así Nunca Encontrarás el Mar')
# (323, 'Cuentas de un Collar')
# (324, 'Mi Sueño de Hoy')
# (325, 'Zonda')
# (326, 'La Orilla Infinita')
# (334, 'Wasabi Flash')
# (335, 'La Luz Te Fue')
# (336, 'El Rebaño del Pastor')
# (337, 'Puyen De Abril')
# (339, 'Cuenco de Sal')
# (340, 'El Sol y la Afeitadora Eléctrica')
# (341, 'Collar')
# (342, 'Duende')

# %%
len(not_found)
# Out:
# 57

# %% [markdown]
# Fracasamos. Vamos a primero marcar los intrumentales

# %%
instrumentales = [118, 122, 127, 128, 130, 135, 146, 147, 152, 154, 156,
                  163, 165, 169, 174, 188, 198, 204, 214, 218, 220, 225, 248, 250, 273, 283,334]
df_tracks.loc[instrumentales, 'Letra'] = '[INSTRUMENTAL]'

# %% [markdown]
# Vamos a usar otra librería a ver si encuentra los que no son instrumentales

# %%
import lyricwikia

not_found = []

for i in df_tracks.index:
    art = df_tracks.loc[i, 'Artista']
    nom = df_tracks.loc[i, 'Nombre']

    if df_tracks.loc[i, 'Letra'] == '':
        try:
            letra = lyricwikia.get_lyrics(song=nom)
            df_tracks.at[i, 'Letra'] = letra.lyrics
            #print(letra.lyrics)
            #clear_output(wait=True)
        except:
            not_found.append((i,nom))
            print(*not_found,sep='\n')
            clear_output(wait=True)
            continue
# Out:
# (290, 'Aguas Claras de Olimpos')
# (296, 'Ven Vení')
# (297, 'Ave Seca')
# (298, 'Donde No Se Lee')
# (300, 'No Me Alcanza')
# (301, 'Ekathé I')
# (302, 'Nómbrala')
# (305, 'Bagatelle')
# (306, 'Ekathé II - Mono')
# (308, 'Guíame')
# (312, 'Los Duendes')
# (313, 'Sub Rebaño')
# (322, 'Así Nunca Encontrarás el Mar')
# (323, 'Cuentas de un Collar')
# (325, 'Zonda')
# (336, 'El Rebaño del Pastor')
# (337, 'Puyen De Abril')
# (339, 'Cuenco de Sal')
# (342, 'Duende')

# %%
len(not_found)
# Out:
# 19

# %% [markdown]
# No hubo éxito. Aparentemente hay algunas letras en Genius pero están bajo otro nombre de artista (`Spinetta y los socios del desierto `vs `Luis Alberto Spinetta`), así que vamos a probar varios

# %%
not_found = []
for i in df_tracks.index:
    #Probar Luis Alberto Spinetta, Spinetta y los Socios del Desierto
    art = 'Spinetta y los Socios del Desierto'
    nom = df_tracks.loc[i, 'Nombre']

    if df_tracks.loc[i, 'Letra'] == '':
        try:
            letra = genius.search_song(nom, artist=art, get_full_info=False)
            df_tracks.at[i, 'Letra'] = letra.lyrics
            print(letra.lyrics)
            clear_output(wait=True)
        except AttributeError:
            not_found.append((i,nom))
            print(*not_found,sep='\n')
            clear_output(wait=True)
            continue
# Out:
# (290, 'Aguas Claras de Olimpos')
# (296, 'Ven Vení')
# (297, 'Ave Seca')
# (298, 'Donde No Se Lee')
# (300, 'No Me Alcanza')
# (301, 'Ekathé I')
# (302, 'Nómbrala')
# (305, 'Bagatelle')
# (306, 'Ekathé II - Mono')
# (308, 'Guíame')
# (312, 'Los Duendes')
# (313, 'Sub Rebaño')
# (322, 'Así Nunca Encontrarás el Mar')
# (323, 'Cuentas de un Collar')
# (325, 'Zonda')
# (334, 'Wasabi Flash')
# (336, 'El Rebaño del Pastor')
# (337, 'Puyen De Abril')
# (339, 'Cuenco de Sal')
# (342, 'Duende')

# %%
len(not_found)
# Out:
# 19

# %%
df_tracks.to_feather('tracks')
